# %%
# Wczytanie danych

import pandas as pd

pokemon = pd.read_csv(r"C:\Users\kudzi\source\repos\Career-Path-Data-Science\Pliki\pokemon.csv", index_col='#')

pokemon
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# #
# 1                Bulbasaur    Grass  Poison    318  45      49       49
# 2                  Ivysaur    Grass  Poison    405  60      62       63
# 3                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 719                Diancie     Rock   Fairy    600  50     100      150
# 719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# ...

# %%
pokemon.info()

# %%
pokemon
pokemon.head(5)
pokemon.tail(5)
pokemon.columns
pokemon.index

# %%
pokemon.columns = [col.lower() for col in pokemon.columns]
pokemon
# Out:
#                       name   type 1  type 2  total  hp  attack  defense  \
# #
# 1                Bulbasaur    Grass  Poison    318  45      49       49
# 2                  Ivysaur    Grass  Poison    405  60      62       63
# 3                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 719                Diancie     Rock   Fairy    600  50     100      150
# 719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 721              Volcanion     Fire   Water    600  80     110      120
#
#      sp. atk  sp. def  speed  generation  legendary
# #
# ...

# %%
pokemon.describe().astype(int)
# Out:
#        total   hp  attack  defense  sp. atk  sp. def  speed  generation
# count    800  800     800      800      800      800    800         800
# mean     435   69      79       73       72       71     68           3
# std      119   25      32       31       32       27     29           1
# min      180    1       5        5       10       20      5           1
# 25%      330   50      55       50       49       50     45           2
# 50%      450   65      75       70       65       70     65           3
# 75%      515   80     100       90       95       90     90           5
# max      780  255     190      230      194      230    180           6

# %%
pokemon.describe().T
# Out:
#             count       mean         std    min     25%    50%    75%    max
# total       800.0  435.10250  119.963040  180.0  330.00  450.0  515.0  780.0
# hp          800.0   69.25875   25.534669    1.0   50.00   65.0   80.0  255.0
# attack      800.0   79.00125   32.457366    5.0   55.00   75.0  100.0  190.0
# defense     800.0   73.84250   31.183501    5.0   50.00   70.0   90.0  230.0
# sp. atk     800.0   72.82000   32.722294   10.0   49.75   65.0   95.0  194.0
# sp. def     800.0   71.90250   27.828916   20.0   50.00   70.0   90.0  230.0
# speed       800.0   68.27750   29.060474    5.0   45.00   65.0   90.0  180.0
# generation  800.0    3.32375    1.661290    1.0    2.00    3.0    5.0    6.0

# %%
pokemon["Attack"]
# Out:
# #
# 1       49
# 2       62
# 3       82
# 3      100
# 4       52
#       ...
# 719    100
# 719    160
# 720    110
# 720    160
# 721    110
# Name: Attack, Length: 800, dtype: int64

# %%
pokemon
pokemon.iloc[0:5]
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur  Grass  Poison    318  45      49       49       65
# 2                Ivysaur  Grass  Poison    405  60      62       63       80
# 3               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# #
# 1       65     45           1      False
# 2       80     60           1      False
# 3      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
pokemon["Attack_AVG"] = pokemon["Attack"].mean()
pokemon["Attack_HP"] = pokemon["Attack"] / pokemon["HP"]
pokemon
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# #
# 1                Bulbasaur    Grass  Poison    318  45      49       49
# 2                  Ivysaur    Grass  Poison    405  60      62       63
# 3                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 719                Diancie     Rock   Fairy    600  50     100      150
# 719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Attack_AVG  Attack_HP
# #
# ...

# %%
import matplotlib.pyplot as plt

pokemon["HP"].hist(bins=100)
# Out:
# <Axes: >

# %%
plt.plot(pokemon["Name"], pokemon["Attack"])

# %%
pokemon
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# #
# 1                Bulbasaur    Grass  Poison    318  45      49       49
# 2                  Ivysaur    Grass  Poison    405  60      62       63
# 3                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 719                Diancie     Rock   Fairy    600  50     100      150
# 719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Attack_AVG  Attack_HP
# #
# ...

# %%
import numpy as np

grupa = pokemon.groupby('Type 1')
result = grupa['HP'].sum()

# Stwórz nowy DataFrame z wynikami
new_df = pd.DataFrame({'grupa': result.index, 'suma': result.values})
print(new_df)


# Zgrupowanie: Zgrupowaliśmy dane według kolumny 'grupa'.
# Obliczenie sumy: Obliczyliśmy sumę wartości w każdej grupie.
# Tworzenie nowego DataFrame: Stworzyliśmy nowy DataFrame z dwiema kolumnami: 'grupa' (indeksy z grupowania) i 'suma' (wyniki obliczeń).
# Out:
#        grupa  suma
# 0        Bug  3925
# 1       Dark  2071
# 2     Dragon  2666
# 3   Electric  2631
# 4      Fairy  1260
# 5   Fighting  1886
# 6       Fire  3635
# 7     Flying   283
# 8      Ghost  2062
# 9      Grass  4709
# 10    Ground  2361
# 11       Ice  1728
# 12    Normal  7573
# 13    Poison  1883
# 14   Psychic  4026
# 15      Rock  2876
# 16     Steel  1761
# 17     Water  8071

# %%
pokemony_po_typie = pokemon.groupby('Type 1')
suma_hp = pokemony_po_typie['HP'].sum()
suma_atak = pokemony_po_typie['Attack'].sum()


pd.DataFrame({'grupa': suma_hp.index, 'suma': suma_hp.values, 'suma_atak': suma_atak.values})
# Out:
#        grupa  suma  suma_atak
# 0        Bug  3925       4897
# 1       Dark  2071       2740
# 2     Dragon  2666       3588
# 3   Electric  2631       3040
# 4      Fairy  1260       1046
# 5   Fighting  1886       2613
# 6       Fire  3635       4408
# 7     Flying   283        315
# 8      Ghost  2062       2361
# 9      Grass  4709       5125
# 10    Ground  2361       3064
# 11       Ice  1728       1746
# 12    Normal  7573       7200
# 13    Poison  1883       2091
# 14   Psychic  4026       4073
# 15      Rock  2876       4086
# 16     Steel  1761       2503
# 17     Water  8071       8305

# %%
plt.figure(figsize=(16, 6))
plt.bar(suma_hp.index, suma_hp.values)
# Out:
# <BarContainer object of 18 artists>

# %%
pokemon.value_counts("Type 1")
# Out:
# Type 1
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Ground       32
# Dragon       32
# Ghost        32
# Dark         31
# Poison       28
# Fighting     27
# Steel        27
# Ice          24
# Fairy        17
# Flying        4
# Name: count, dtype: int64

# %%
import pandas as pd
import numpy as np

res = pd.Series(index_col =pokemon["Name"], data=pokemon["Attack"], name="Attack").squeeze()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[74], line 4
#       1 import pandas as pd
#       2 import numpy as np
# ----> 4 res = pd.Series(index=pokemon["Name"], data=pokemon["Attack"], name="Attack").squeeze()
#
# File c:\Users\kudzi\source\repos\Career-Path-Data-Science\.venv\Lib\site-packages\pandas\core\series.py:533, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     531     data = data._mgr.copy(deep=False)
#     532 else:
# --> 533     data = data.reindex(index, copy=copy)
#     534     copy = False
#     535     data = data._mgr
#
# File c:\Users\kudzi\source\repos\Career-Path-Data-Science\.venv\Lib\site-packages\pandas\core\series.py:5153, in Series.reindex(self, index, axis, method, copy, level, fill_value, limit, tolerance)
#    5136 @doc(
#    5137     NDFrame.reindex,  # type: ignore[has-type]
# ...
